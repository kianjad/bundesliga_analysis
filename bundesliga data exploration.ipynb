# %%
import pandas as pd

# %%
df = pd.read_csv("sample_dataset.csv")
df.head()
# Out:
#        EVENT_ID  MUID  PUID1  CUID1  PUID2  CUID2  NOMATCH GDCP_EVENT_TIME  \
# 0  1.820650e+13   101  810.0   18.0  799.0   18.0        0         31:14.1
# 1  1.820650e+13   101  799.0   18.0  807.0   18.0        0         31:17.0
# 2  1.820650e+13   101  807.0   18.0  244.0    6.0        0         31:21.6
# 3  1.820650e+13   101  244.0    6.0    NaN    NaN        0         31:24.1
# 4  1.820650e+13   101  244.0    6.0  814.0   18.0        0         31:24.7
#
#   TRACKING_TIME  X_EVENT  ...  GOAL_DISTANCE  Y_SIDE  X_DELTA Y_CHANGE  \
# 0       31:14.1      0.0  ...         50.100       1      NaN        1
# 1       31:17.1     14.6  ...         33.916       1     16.3        0
# 2       31:20.0    -46.8  ...         55.692       1     13.5        0
# 3       31:30.6    -45.1  ...         33.185       1     49.2        0
# 4       31:26.1    -41.9  ...         33.264       1      0.2        0
#
#    GOAL_DIST_DELTA  Y_DELTA XY_DELTA  TIME_DELTA  EVENT_SPEED  ReceiveInt
# ...

# %%
df.columns.to_list()
# Out:
# ['EVENT_ID',
#  'MUID',
#  'PUID1',
#  'CUID1',
#  'PUID2',
#  'CUID2',
#  'NOMATCH',
#  'GDCP_EVENT_TIME',
#  'TRACKING_TIME',
#  'X_EVENT',
#  'Y_EVENT',
#  'X_TRACKING',
#  'Y_TRACKING',
#  'SUBTYPE',
#  'FRAME_NUMBER',
#  'GDCP_EVENT_ID',
#  'NORECEIVER',
#  'XRec',
#  'YRec',
#  'RECFRM',
#  'EVALUATION',
#  'Goingright',
#  'PRESSURE',
#  'PRESSER',
#  'PRESSURE_RECEIVER',
#  'PRESSER_REC',
#  'Bypassed_Players',
#  'Bypassed_Defenders',
#  'xG',
#  'PENALTY',
#  'AssistTyp',
#  'DISTANCE',
#  'ANGLE',
#  'FREEKICK',
#  'FOOT',
#  'SPEED',
#  'PRESSURE_ON_SHOT',
#  'DEFENDERS',
#  'DISTANCE_GOALKEEPER',
#  'GK_INGOAL',
#  'Rotation',
#  'xPass',
#  'PossSpeed',
#  'PossAng',
#  'Dis_nearest_opp_rec',
#  'Dist_of_pass',
#  'Nearest_Defender_to_passing_lane',
#  'Angle_of_pass',
#  'OneTouch',
#  'Time_of_Possesion',
#  'BlockProb',
#  'Opp_Players_in_path',
#  'MIN_AVG_SPEED',
#  'MIN_VAR_SPEED',
#  'MIN_AVG_OWN_EVENT_SPEED',
#  'MIN_AVG_GOAL_DIST',
#  'MIN_VAR_GOAL_DIST',
# ...

# %% [markdown]
# push and pull to github every time starting and ending coding
# 1. cut off the extra columns after opposing players in path
# 2. export as new dataset, replace the old it with the new dataset, then delete code used to make new dataset
# 3. eda, look up examples, ask chat, investigate data and columns
# 4. analysis: create dashboard and do player statistics/scores
# 5. conclusion: findings, anything interesting
#
# bonus: find the game
